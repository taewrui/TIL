# %%
data = [None for i in range(100000)]
pre = [None for i in range(1000000)]
nxt = [None for i in range(1000000)]

# %%
unused = 0

# %%
def traverse():
    cur = nxt[0]
    while cur != -1:
        print(data[cur])
        cur = nxt[cur]

# %%
def insert(add, dat, unused):
    data[unused] = dat
    pre[unused] = add
    nxt[unused] = nxt[add]
    if(nxt[add] != -1 and nxt[add] is not None):
        pre[nxt[add]] = unused
    nxt[add] = unused
    unused += 1
    return unused

# %%
def erase(add):
    nxt[pre[add]] = nxt[add]
    if nxt[add] != -1:
        pre[nxt[add]] = pre[add]

# %%
com = input()
n = int(input())
list = ["" for i in range(n)]
for i in range(n):
    list[i] = input()
# Out:
# abcd
# 3
# P x
# L
# P y

# %%
data[0] = -1
pre[0] = -1
nxt[0] = -1

# %%
for n, i in enumerate(s):
    print(n, i)
    unused = insert(n+1, i, unused)
# Out:
# 0 a
# 1 b
# 2 c
# 3 d

# %%
cur = len(com)

# %%
for i in list:
    print(i[0])
    if i[0] == 'L':
        if pre[cur] != 0 and pre[cur] is not None:
            cur = pre[cur]
    elif i[0] == 'D':
        if nxt[cur] is not None:
            cur = nxt[cur]
    elif i[0] == 'B':
        if pre[cur] != 0 and pre[cur] is not None:
            erase(pre[cur])
            
    elif i[0] == 'P':
        unused = insert(cur, i[1], unused)
        
for i in data:
    print(i)
# Out:
# P
# L
# P
# -1
# b
# c
# d
#
#
#
#
#
#
# a
# b
# c
# d
#
#
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# ...
